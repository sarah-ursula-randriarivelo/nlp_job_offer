# %%
# %run vectorizing.ipynb import X
# %run clean_text.ipynb import df_clean_text as df
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score


def find_optimal_clusters(X, max_k = 50):

#the maximum number of cluster should not exceed the half of the documents length
    max_possible_k = min(max_k, len(df) // 2)
    if max_possible_k < 2:
         return 2

# we want to test for each number of cluster which gives the best score
 
    k_range = range(2, max_possible_k)

# we will stock each cluster its corresponding score inside the "scores" table 
    scores = []
    
    for k in k_range:
        try:
            kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
            kmeans.fit(X)
            score = silhouette_score(X, kmeans.labels_)
            scores.append(score)
            # print(f"cluster : {k}, score:{score}")
        except:
            scores.append(-1)  #  Clustering errors

    if not scores or all(s == -1 for s in scores):
        return 2

    best_k = k_range [scores.index(max(scores))]
    print(f"best_k = {best_k}, score = {score}")
    return best_k
    

# if __name__ == "__main__" :

n_clusters = find_optimal_clusters(X) 

kmeans = KMeans(n_clusters=n_clusters, random_state=42, n_init=10)

df['cluster'] = kmeans.fit_predict(X)

df_optimal = df['cluster']
# Out:
# !!We've got 1000 lines retrieved from the database !!
# !!We've got 1000 lines retrieved from the database !!
# !!We've got 1000 lines retrieved from the database !!
# this is the class vectorize: TfidfVectorizer(max_df=0.8, max_features=50, min_df=2, ngram_range=(2, 3),
#                 stop_words=['aie', 'pas', 'plus', 'avons', 'aurait', 'à', 'ma',
#                             'aura', 'fus', 'ont', 'ni', 'eusse', 'eûmes', 'il',
#                             'ne', 'trop', 'aviez', 'te', 'étante', 'sois', 'un',
#                             'd', 'était', 'eus', 'car', 'étantes', 'vous', 'y',
#                             'dans', 'étée', ...])
# this is the document term matrix: <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 437 stored elements and shape (1000, 50)>
#   Coords	Values
#   (4, 7)	1.0
#   (15, 48)	1.0
#   (16, 48)	1.0
#   (17, 48)	1.0
#   (18, 48)	1.0
#   (19, 48)	1.0
#   (20, 48)	1.0
#   (31, 46)	0.5773502691896257
#   (31, 1)	0.5773502691896257
#   (31, 47)	0.5773502691896257
#   (32, 46)	0.5773502691896257
#   (32, 1)	0.5773502691896257
#   (32, 47)	0.5773502691896257
#   (33, 46)	0.5773502691896257
#   (33, 1)	0.5773502691896257
#   (33, 47)	0.5773502691896257
#   (34, 46)	0.5773502691896257
#   (34, 1)	0.5773502691896257
#   (34, 47)	0.5773502691896257
#   (35, 46)	0.5773502691896257
#   (35, 1)	0.5773502691896257
#   (35, 47)	0.5773502691896257
#   (36, 46)	0.5773502691896257
#   (36, 1)	0.5773502691896257
#   (36, 47)	0.5773502691896257
#   :	:
#   (941, 14)	1.0
#   (942, 14)	1.0
#   (943, 14)	1.0
#   (944, 14)	1.0
#   (945, 14)	1.0
#   (949, 13)	1.0
#   (950, 13)	1.0
#   (951, 13)	1.0
#   (973, 17)	1.0
#   (974, 12)	1.0
#   (975, 12)	1.0
#   (976, 12)	1.0
#   (977, 12)	1.0
#   (978, 16)	1.0
#   (979, 16)	1.0
#   (980, 16)	1.0
#   (984, 14)	1.0
#   (985, 6)	0.76464439719777
#   (985, 14)	0.644452438768028
#   (986, 6)	0.76464439719777
#   (986, 14)	0.644452438768028
#   (987, 14)	1.0
#   (988, 14)	1.0
#   (990, 13)	1.0
#   (991, 13)	1.0
# 4, marketing digital, 1.0
# 15, web merchandiser, 1.0
# 16, web merchandiser, 1.0
# 17, web merchandiser, 1.0
# 18, web merchandiser, 1.0
# 19, web merchandiser, 1.0
# 20, web merchandiser, 1.0
# 31, virtual assistant, 0.5773502691896257
# 31, assistant direction, 0.5773502691896257
# 31, virtual assistant direction, 0.5773502691896257
# 32, virtual assistant, 0.5773502691896257
# 32, assistant direction, 0.5773502691896257
# 32, virtual assistant direction, 0.5773502691896257
# 33, virtual assistant, 0.5773502691896257
# 33, assistant direction, 0.5773502691896257
# 33, virtual assistant direction, 0.5773502691896257
# 34, virtual assistant, 0.5773502691896257
# 34, assistant direction, 0.5773502691896257
# 34, virtual assistant direction, 0.5773502691896257
# 35, virtual assistant, 0.5773502691896257
# 35, assistant direction, 0.5773502691896257
# 35, virtual assistant direction, 0.5773502691896257
# 36, virtual assistant, 0.5773502691896257
# 36, assistant direction, 0.5773502691896257
# 36, virtual assistant direction, 0.5773502691896257
# 37, virtual assistant, 0.5773502691896257
# 37, assistant direction, 0.5773502691896257
# 37, virtual assistant direction, 0.5773502691896257
# 45, vendeurs conseil, 1.0
# 46, vendeurs conseil, 1.0
# 47, vendeurs conseil, 1.0
# 48, vendeurs conseil, 1.0
# 49, vendeurs conseil, 1.0
# 50, vendeurs conseil, 1.0
# 51, vendeurs conseil, 1.0
# 52, vendeurs conseil, 1.0
# 53, vendeurs conseil, 1.0
# 54, vendeurs conseil, 1.0
# 55, vendeurs conseil, 1.0
# 56, vendeurs conseil, 1.0
# 57, vendeurs conseil, 1.0
# 58, vendeurs conseil, 1.0
# 59, vendeurs conseil, 1.0
# 60, vendeurs conseil, 1.0
# 61, vendeurs conseil, 1.0
# 62, vendeurs conseil, 1.0
# 63, vendeurs conseil, 1.0
# 64, vendeurs conseil, 1.0
# 65, vendeurs conseil, 0.40200610947304727
# 65, conseil materiaux, 0.5330832961881251
# 65, materiaux construction, 0.5196493881423816
# 65, conseil materiaux construction, 0.5330832961881251
# 66, vendeurs conseil, 0.40200610947304727
# 66, conseil materiaux, 0.5330832961881251
# 66, materiaux construction, 0.5196493881423816
# 66, conseil materiaux construction, 0.5330832961881251
# 67, vendeurs conseil, 0.40200610947304727
# 67, conseil materiaux, 0.5330832961881251
# 67, materiaux construction, 0.5196493881423816
# 67, conseil materiaux construction, 0.5330832961881251
# 68, vendeurs conseil, 0.40200610947304727
# 68, conseil materiaux, 0.5330832961881251
# 68, materiaux construction, 0.5196493881423816
# 68, conseil materiaux construction, 0.5330832961881251
# 69, vendeurs conseil, 0.40200610947304727
# 69, conseil materiaux, 0.5330832961881251
# 69, materiaux construction, 0.5196493881423816
# 69, conseil materiaux construction, 0.5330832961881251
# 70, vendeurs conseil, 1.0
# 101, marketing communication, 1.0
# 107, poste base, 1.0
# 124, technicien production, 1.0
# 125, technicien production, 1.0
# 180, testeur qa, 1.0
# 181, marketing digital, 1.0
# 215, charge communication, 1.0
# 216, charge communication, 1.0
# 217, charge communication, 1.0
# 218, charge communication, 1.0
# 222, charge communication, 1.0
# 227, marketing communication, 1.0
# 246, marketing digital, 1.0
# 248, technico commercial, 1.0
# 253, technicien maintenance, 1.0
# 254, technicien maintenance, 1.0
# 255, superviseur credit, 1.0
# 256, superviseur commercial, 1.0
# 257, superviseur commercial, 1.0
# 258, superviseur call, 1.0
# 259, superviseur call, 1.0
# 260, superviseur call, 1.0
# 261, superviseur call, 1.0
# 262, superviseur call, 1.0
# 263, superviseur call, 1.0
# 264, superviseur call, 1.0
# 270, stagiaire recrutement, 1.0
# 274, poste base, 1.0
# 276, marketing communication, 1.0
# 278, poste base, 1.0
# 279, ressources humaines, 1.0
# 291, redacteur web, 0.5773502691896257
# 291, web polyvalent, 0.5773502691896257
# 291, redacteur web polyvalent, 0.5773502691896257
# 292, redacteur web, 0.5773502691896257
# 292, web polyvalent, 0.5773502691896257
# 292, redacteur web polyvalent, 0.5773502691896257
# 293, redacteur web, 0.5773502691896257
# 293, web polyvalent, 0.5773502691896257
# 293, redacteur web polyvalent, 0.5773502691896257
# 294, redacteur web, 0.5773502691896257
# 294, web polyvalent, 0.5773502691896257
# 294, redacteur web polyvalent, 0.5773502691896257
# 295, redacteur web, 0.5773502691896257
# 295, web polyvalent, 0.5773502691896257
# 295, redacteur web polyvalent, 0.5773502691896257
# 317, poste base, 1.0
# 342, marketing communication, 1.0
# 345, marketing digital, 1.0
# 355, support technique, 1.0
# 390, traffic manager, 1.0
# 391, traffic manager, 1.0
# 392, traffic manager, 1.0
# 393, traffic manager, 1.0
# 394, traffic manager, 1.0
# 402, testeur qa, 1.0
# 403, testeur qa, 1.0
# 404, testeur qa, 1.0
# 405, testeur qa, 1.0
# 406, testeur logiciel, 1.0
# 407, testeur logiciel, 1.0
# 408, testeur logiciel, 1.0
# 409, testeur logiciel, 1.0
# 410, testeur logiciel, 1.0
# 433, telesecretaire medicale, 1.0
# 434, telesecretaire medicale, 1.0
# 435, telesecretaire medicale, 1.0
# 436, telesecretaire medicale, 1.0
# 437, telesecretaire medicale, 1.0
# 438, telesecretaire medicale, 1.0
# 439, telesecretaire medicale, 1.0
# 440, telesecretaire medicale, 1.0
# 478, teleoperateurs teleoperatrices, 1.0
# 479, teleoperateurs teleoperatrices, 0.4587119973215896
# 479, teleoperatrices bilingues, 0.5173336474930881
# 479, bilingues francais, 0.5042966367687103
# 479, teleoperatrices bilingues francais, 0.5173336474930881
# 480, teleoperateurs teleoperatrices, 0.4587119973215896
# 480, teleoperatrices bilingues, 0.5173336474930881
# 480, bilingues francais, 0.5042966367687103
# 480, teleoperatrices bilingues francais, 0.5173336474930881
# 481, teleoperateurs teleoperatrices, 0.4587119973215896
# 481, teleoperatrices bilingues, 0.5173336474930881
# 481, bilingues francais, 0.5042966367687103
# 481, teleoperatrices bilingues francais, 0.5173336474930881
# 482, teleoperateurs teleoperatrices, 0.4587119973215896
# 482, teleoperatrices bilingues, 0.5173336474930881
# 482, bilingues francais, 0.5042966367687103
# 482, teleoperatrices bilingues francais, 0.5173336474930881
# 483, teleoperateurs teleoperatrices, 0.4587119973215896
# 483, teleoperatrices bilingues, 0.5173336474930881
# 483, bilingues francais, 0.5042966367687103
# 483, teleoperatrices bilingues francais, 0.5173336474930881
# 484, teleoperateurs teleoperatrices, 0.5312053299523446
# 484, teleoperatrices anglophones, 0.5990913525624538
# 484, teleoperateurs teleoperatrices anglophones, 0.5990913525624538
# 485, teleoperateurs teleoperatrices, 0.5312053299523446
# 485, teleoperatrices anglophones, 0.5990913525624538
# 485, teleoperateurs teleoperatrices anglophones, 0.5990913525624538
# 486, teleoperateurs teleoperatrices, 0.5312053299523446
# 486, teleoperatrices anglophones, 0.5990913525624538
# 486, teleoperateurs teleoperatrices anglophones, 0.5990913525624538
# 487, teleoperateurs teleoperatrices, 0.5312053299523446
# 487, teleoperatrices anglophones, 0.5990913525624538
# 487, teleoperateurs teleoperatrices anglophones, 0.5990913525624538
# 488, teleoperateurs teleoperatrices, 0.5312053299523446
# 488, teleoperatrices anglophones, 0.5990913525624538
# 488, teleoperateurs teleoperatrices anglophones, 0.5990913525624538
# 490, bilingues francais, 1.0
# 495, teleoperateur teleoperatrice, 1.0
# 496, teleoperateur teleoperatrice, 1.0
# 497, teleoperateur teleoperatrice, 1.0
# 498, teleoperateur teleoperatrice, 1.0
# 509, teleoperateur teleoperatrice, 1.0
# 546, technico commercial, 1.0
# 547, technico commercial, 1.0
# 548, technico commercial, 1.0
# 549, technico commercial, 1.0
# 550, technico commercial, 1.0
# 551, technico commercial, 1.0
# 552, technico commercial, 1.0
# 553, technico commercial, 1.0
# 554, technico commercial, 1.0
# 555, technico commercial, 1.0
# 556, technico commercial, 1.0
# 557, technico commercial, 1.0
# 558, poste base, 0.8038585175656877
# 558, technico commercial, 0.5948205475074773
# 559, materiaux construction, 0.8038585175656877
# 559, technico commercial, 0.5948205475074773
# 560, technico commercial, 1.0
# 561, technico commercial, 1.0
# 562, technico commercial, 1.0
# 563, technico commercial, 1.0
# 564, technico commercial, 1.0
# 565, technico commercial, 1.0
# 566, technico commercial, 1.0
# 567, technico commercial, 1.0
# 568, technico commercial, 1.0
# 569, technico commercial, 1.0
# 570, technico commercial, 1.0
# 571, technico commercial, 1.0
# 572, technico commercial, 1.0
# 573, technico commercial, 1.0
# 574, technico commercial, 1.0
# 575, technico commercial, 1.0
# 576, technico commercial, 1.0
# 592, technicien support, 1.0
# 593, technicien support, 1.0
# 594, technicien support, 1.0
# 595, technicien support, 1.0
# 596, technicien support, 0.6728819928964302
# 596, support it, 0.7397498385506606
# 597, technicien support, 0.6728819928964302
# 597, support it, 0.7397498385506606
# 598, technicien support, 0.6728819928964302
# 598, support it, 0.7397498385506606
# 599, technicien support, 1.0
# 600, technicien support, 1.0
# 601, technicien support, 1.0
# 602, technicien support, 1.0
# 623, technicien polyvalent, 1.0
# 624, technicien polyvalent, 1.0
# 625, technicien polyvalent, 1.0
# 626, technicien polyvalent, 1.0
# 627, technicien polyvalent, 1.0
# 628, technicien polyvalent, 1.0
# 629, technicien polyvalent, 1.0
# 630, technicien polyvalent, 1.0
# 633, technicien maintenance, 1.0
# 638, technicien informatique, 1.0
# 639, technicien informatique, 1.0
# 640, technicien informatique, 1.0
# 641, technicien informatique, 1.0
# 655, technicien maintenance, 1.0
# 656, technicien installation, 1.0
# 657, technicien informatique, 1.0
# 669, technicien production, 1.0
# 670, technicien production, 1.0
# 671, technicien production, 1.0
# 672, technicien maintenance, 1.0
# 673, technicien maintenance, 1.0
# 674, technicien maintenance, 1.0
# 675, technicien maintenance, 1.0
# 676, technicien maintenance, 1.0
# 677, technicien maintenance, 1.0
# 678, technicien maintenance, 1.0
# 679, technicien maintenance, 1.0
# 680, technicien maintenance, 1.0
# 681, technicien maintenance, 1.0
# 682, technicien maintenance, 1.0
# 683, poste base, 0.7833986331980085
# 683, technicien maintenance, 0.6215195745135402
# 684, technicien maintenance, 1.0
# 685, technicien maintenance, 1.0
# 686, technicien maintenance, 1.0
# 687, technicien maintenance, 1.0
# 688, technicien maintenance, 1.0
# 689, technicien maintenance, 1.0
# 694, technicien installation, 1.0
# 695, technicien installation, 1.0
# 696, technicien installation, 1.0
# 697, technicien installation, 1.0
# 716, team leader, 1.0
# 717, team leader, 1.0
# 718, team leader, 1.0
# 719, team leader, 1.0
# 720, team leader, 1.0
# 721, team leader, 1.0
# 722, team leader, 1.0
# 723, team leader, 1.0
# 724, team leader, 1.0
# 725, team leader, 1.0
# 726, team leader, 1.0
# 727, team leader, 1.0
# 728, team leader, 1.0
# 729, team leader, 1.0
# 730, team leader, 1.0
# 731, team leader, 1.0
# 732, team leader, 1.0
# 733, team leader, 1.0
# 734, team leader, 1.0
# 735, team lead, 1.0
# 736, team lead, 1.0
# 737, team lead, 1.0
# 738, team lead, 1.0
# 739, team lead, 1.0
# 742, talent acquisition, 0.5484901089915193
# 742, acquisition specialist, 0.591252315149155
# 742, talent acquisition specialist, 0.591252315149155
# 743, talent acquisition, 0.5484901089915193
# 743, acquisition specialist, 0.591252315149155
# 743, talent acquisition specialist, 0.591252315149155
# 744, talent acquisition, 0.5484901089915193
# 744, acquisition specialist, 0.591252315149155
# 744, talent acquisition specialist, 0.591252315149155
# 745, talent acquisition, 0.5484901089915193
# 745, acquisition specialist, 0.591252315149155
# 745, talent acquisition specialist, 0.591252315149155
# 746, talent acquisition, 0.5484901089915193
# 746, acquisition specialist, 0.591252315149155
# 746, talent acquisition specialist, 0.591252315149155
# 747, talent acquisition, 0.5484901089915193
# 747, acquisition specialist, 0.591252315149155
# 747, talent acquisition specialist, 0.591252315149155
# 748, talent acquisition, 0.5484901089915193
# 748, acquisition specialist, 0.591252315149155
# 748, talent acquisition specialist, 0.591252315149155
# 749, talent acquisition, 0.5484901089915193
# 749, acquisition specialist, 0.591252315149155
# 749, talent acquisition specialist, 0.591252315149155
# 750, talent acquisition, 0.5484901089915193
# 750, acquisition specialist, 0.591252315149155
# 750, talent acquisition specialist, 0.591252315149155
# 751, talent acquisition, 1.0
# 752, talent acquisition, 1.0
# 753, talent acquisition, 1.0
# 754, talent acquisition, 1.0
# 755, talent acquisition, 1.0
# 762, support technique, 1.0
# 763, support technique, 1.0
# 764, support technique, 1.0
# 765, support technique, 1.0
# 766, support technique, 1.0
# 767, support technique, 1.0
# 773, support it, 1.0
# 774, support it, 1.0
# 775, support it, 1.0
# 789, superviseur comptable, 1.0
# 790, superviseur comptable, 1.0
# 824, superviseur credit, 1.0
# 825, superviseur credit, 1.0
# 826, superviseur credit, 1.0
# 827, superviseur credit, 1.0
# 828, superviseur credit, 1.0
# 829, superviseur credit, 1.0
# 830, superviseur credit, 1.0
# 836, superviseur comptable, 1.0
# 837, superviseur comptable, 1.0
# 838, superviseur comptable, 1.0
# 839, superviseur comptable, 1.0
# 840, superviseur comptable, 1.0
# 841, superviseur comptable, 1.0
# 842, superviseur comptable, 1.0
# 843, superviseur comptable, 1.0
# 844, superviseur comptable, 1.0
# 845, superviseur comptable, 1.0
# 846, superviseur comptable, 1.0
# 847, superviseur comptable, 1.0
# 848, superviseur comptable, 1.0
# 849, superviseur comptable, 1.0
# 850, superviseur comptable, 1.0
# 851, superviseur comptable, 1.0
# 852, superviseur commercial, 1.0
# 853, superviseur commercial, 1.0
# 854, superviseur commercial, 1.0
# 858, superviseur call, 1.0
# 859, superviseur call, 1.0
# 860, superviseur call, 1.0
# 861, superviseur call, 1.0
# 889, technicien maintenance, 1.0
# 894, ressources humaines, 0.7806781442863252
# 894, stagiaire rh, 0.6249333044682924
# 895, stagiaire rh, 1.0
# 896, stagiaire rh, 1.0
# 897, stagiaire rh, 1.0
# 898, stagiaire rh, 1.0
# 899, stagiaire rh, 1.0
# 900, stagiaire rh, 1.0
# 901, stagiaire rh, 1.0
# 902, stagiaire rh, 1.0
# 903, stagiaire rh, 1.0
# 904, stagiaire rh, 1.0
# 905, stagiaire rh, 1.0
# 906, stagiaire rh, 1.0
# 907, stagiaire rh, 1.0
# 908, stagiaire rh, 1.0
# 909, stagiaire rh, 1.0
# 910, stagiaire rh, 1.0
# 911, stagiaire rh, 1.0
# 912, stagiaire rh, 1.0
# 913, stagiaire rh, 1.0
# 914, stagiaire rh, 1.0
# 916, stagiaire recrutement, 1.0
# 917, stagiaire recrutement, 1.0
# 918, stagiaire recrutement, 1.0
# 920, stagiaire qualite, 1.0
# 921, stagiaire qualite, 1.0
# 922, stagiaire qualite, 1.0
# 923, stagiaire qualite, 1.0
# 924, stagiaire qualite, 1.0
# 932, stagiaire marketing, 1.0
# 933, marketing digital, 0.7717749468089078
# 933, stagiaire marketing, 0.635895770923276
# 934, marketing digital, 0.7717749468089078
# 934, stagiaire marketing, 0.635895770923276
# 935, stagiaire marketing, 1.0
# 936, stagiaire marketing, 1.0
# 937, marketing communication, 0.76464439719777
# 937, stagiaire marketing, 0.644452438768028
# 938, stagiaire marketing, 1.0
# 939, stagiaire marketing, 1.0
# 940, stagiaire marketing, 1.0
# 941, stagiaire marketing, 1.0
# 942, stagiaire marketing, 1.0
# 943, stagiaire marketing, 1.0
# 944, stagiaire marketing, 1.0
# 945, stagiaire marketing, 1.0
# 949, stagiaire logistique, 1.0
# 950, stagiaire logistique, 1.0
# 951, stagiaire logistique, 1.0
# 973, stagiaire rh, 1.0
# 974, ressources humaines, 1.0
# 975, ressources humaines, 1.0
# 976, ressources humaines, 1.0
# 977, ressources humaines, 1.0
# 978, stagiaire recrutement, 1.0
# 979, stagiaire recrutement, 1.0
# 980, stagiaire recrutement, 1.0
# 984, stagiaire marketing, 1.0
# 985, marketing communication, 0.76464439719777
# 985, stagiaire marketing, 0.644452438768028
# 986, marketing communication, 0.76464439719777
# 986, stagiaire marketing, 0.644452438768028
# 987, stagiaire marketing, 1.0
# 988, stagiaire marketing, 1.0
# 990, stagiaire logistique, 1.0
# 991, stagiaire logistique, 1.0
# !!We've got 1000 lines retrieved from the database !!
# !!We've got 1000 lines retrieved from the database !!
# !!We've got 1000 lines retrieved from the database !!
# best_k = 49, score = 0.994
